# %%
# Import necessary modules
# glob allows unix style pathname pattern expansion
from glob import glob
# pydicom is the python dicom reader
import pydicom as dicom

# %%
# 5-T1w_MPR_vNav -- MPRAGE structrual dicoms

# directories will have to be specific to your computer
base_dir = '/Users/emusser/Documents/GitHub'
proj_dir = '/mattfeld_2020/code'
subj_dir = '/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/'

# with strings I can concatenate them with simple addition lines
data_dir = base_dir + proj_dir + subj_dir


# Here I use glob to grab the dicom files
# Why would I use glob?  What does it give me?
data_files = glob(data_dir + '/*')

# %%
print(data_files)
# Out:
# ['/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-147-d31eex.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-140-1rhopu5.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-156-7c7age.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-154-9fr2s3.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-16-1lkn56e.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-37-1ohpnvr.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-9-1pnzo71.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-130-a8au40.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-15-1psr6uu.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-58-1p1ecsl.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-44-66eqkh.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-84-ksk6e8.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-145-17l87p7.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-164-1dhssz2.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-11-1ht73dv.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-70-1k317hr.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-65-b3626l.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-74-1hxdjal.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-5-107-oviloz.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/5-T1w_MPR_vNav/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.300000190 ...

# %%
# Here I am using the python dicom reader to read in a dicom header
# What should go between the square brackets []
data_set = dicom.dcmread(data_files[0])

# %%
print(data_set)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.43.166003.2019061915241161003513836
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# (0002, 0016) Source Application Entity Title     AE: 'AN_MEDCOMNT204'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
# (0008, 0012) Instance Creation Date              DA: '20190619'
# (0008, 0013) Instance Creation Time              TM: '152413.677000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.43.166003.2019061915241161003513836
# (0008, 0020) Study Date                          DA: '20190619'
# (0008, 0021) Series Date                         DA: '20190619'
# (0008, 0022) Acquisition Date                    DA: '20190619'
# (0008, 0023) Content Date                        DA: '20190619'
# (0008, 0030) Study Time                          TM: '150037.662000'
# (0008, 0031) Series Time                         TM: '152413.328000'
# (0008, 0032) Acquisition Time                    TM: '151756.262500'
# (0008, 0033) Content Time                        TM: '152413.677000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'FIU Center For Imaging Science'
# (0008, 0081) Institution Address                 ST: 'SW 8TH ST, OE116 11200,MIAMI,Med-Lab,US,33199'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP166003'
# (0008, 1030) Study Description                   LO: 'Mattfeld_REVL'
# (0008, 103e) Series Description                  LO: 'T1w_MPR_vNav'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1070) Operators' Name                     PN: 'RR'
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163521984993764
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163172628493761
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915162823169893758
#    ---------
# (0010, 0010) Patient's Name                      PN: 'Mattfeld_REVL-000-vCAT-021'
# (0010, 0020) Patient ID                          LO: 'Mattfeld_REVL-000-vCAT-021-S1'
# (0010, 0030) Patient's Birth Date                DA: '19770101'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '042Y'
# (0010, 1020) Patient's Size                      DS: "1.82880366"
# (0010, 1030) Patient's Weight                    DS: "84.3681915522"
# (0010, 4000) Patient Comments                    LT: 'Project: Mattfeld_REVL;Mattfeld_REVL-000-vCAT-021 ; Session: Mattfeld_REVL-000-vCAT-021-S1'
# (0012, 0064)  De-identification Method Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '2'
#    (0008, 0102) Coding Scheme Designator            SH: 'XNAT'
#    (0008, 0103) Coding Scheme Version               SH: '0.1'
#    (0008, 0104) Code Meaning                        LO: 'XNAT Edit Script'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'BRAIN'
# (0018, 0020) Scanning Sequence                   CS: ['GR', 'IR']
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'MP']
# (0018, 0022) Scan Options                        CS: ['IR', 'WE']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'tfl3d1_16ns'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "1.0"
# (0018, 0080) Repetition Time                     DS: "2500.0"
# (0018, 0081) Echo Time                           DS: "2.9"
# (0018, 0082) Inversion Time                      DS: "1070.0"
# (0018, 0083) Number of Averages                  DS: "1.0"
# (0018, 0084) Imaging Frequency                   DS: "123.249149"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3.0"
# (0018, 0089) Number of Phase Encoding Steps      IS: "255"
# (0018, 0091) Echo Train Length                   IS: "1"
# (0018, 0093) Percent Sampling                    DS: "100.0"
# (0018, 0094) Percent Phase Field of View         DS: "100.0"
# (0018, 0095) Pixel Bandwidth                     DS: "240.0"
# (0018, 1000) Device Serial Number                LO: '166003'
# (0018, 1020) Software Versions                   LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'T1w_MPR_vNav'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [0, 256, 256, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: "8.0"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.03557668599229"
# (0018, 1318) dB/dt                               DS: "0.0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0019, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0019, 100b) [SliceMeasurementDuration]          DS: "0.0"
# (0019, 100f) [GradientMode]                      SH: 'Fast'
# (0019, 1011) [FlowCompensation]                  SH: 'No'
# (0019, 1012) [TablePositionOrigin]               SL: [0, 0, -1306]
# (0019, 1013) [ImaAbsTablePosition]               SL: [0, 0, -1306]
# (0019, 1014) [ImaRelTablePosition]               IS: [0, 0, 0]
# (0019, 1015) [SlicePosition_PCS]                 FD: [54.86803865, -151.17331696, 130.23434758]
# (0019, 1017) [SliceResolution]                   DS: "1.0"
# (0019, 1018) [RealDwellTime]                     IS: "8200"
# (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.43.166003.2019061915174069268094190.0.0.0
# (0020, 0010) Study ID                            SH: '1'
# (0020, 0011) Series Number                       IS: "5"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "147"
# (0020, 0032) Image Position (Patient)            DS: [54.868038654327, -151.17331695557, 130.23434758186]
# (0020, 0037) Image Orientation (Patient)         DS: [0, 1, 0, 0, 0, -1]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.43.166003.1.20190619151307196.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "54.868038654327"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: [1, 1]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 1435
# (0028, 1050) Window Center                       DS: "652.0"
# (0028, 1051) Window Width                        DS: "1367.0"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 0012) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0029, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0029, 1009) [CSA Image Header Version]          LO: '20190619'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 11156 elements
# (0029, 1018) [CSA Series Header Type]            CS: 'MR'
# (0029, 1019) [CSA Series Header Version]         LO: '20190619'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 140056 elements
# (0029, 1120) [MedCom History Information]        OB: Array of 308 elements
# (0029, 1260) [Series Workflow Status]            LO: 'com'
# (0040, 0244) Performed Procedure Step Start Date DA: '20190619'
# (0040, 0245) Performed Procedure Step Start Time TM: '150037.732000'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR20190619150037'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Mattfeld_REVL^Mattfeld_REVL'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0051, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0051, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0051, 100a) [Unknown]                           LO: 'TA 00.00'
# (0051, 100b) [AcquisitionMatrixText]             LO: '256*256'
# (0051, 100c) [Unknown]                           LO: 'FoV 256*256'
# (0051, 100d) [Unknown]                           SH: 'SP L54.9'
# (0051, 100e) [Unknown]                           LO: 'Sag'
# (0051, 100f) [CoilString]                        LO: 'HEA;HEP'
# (0051, 1011) [PATModeText]                       LO: 'p2'
# (0051, 1012) [Unknown]                           SH: 'TP 0'
# (0051, 1013) [PositivePCSDirections]             SH: '+LPH'
# (0051, 1016) [Unknown]                           LO: 'p2 M/ND/NORM'
# (0051, 1017) [Unknown]                           SH: 'SL 1.0'
# (0051, 1019) [Unknown]                           LO: 'A1/IR/WE'
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 elements

# %%
# Elements we're interested in
# Repetition Time
# Echo Time
# Acquisition Matrix 
# Flip Angle
# Acquisition Number
# Protocol Name
# Slice times = data_set[0x00191029].value

print('The number of TRs collected equals: {0}'.format(len(data_files)))
print('The timing of the TR was: {0} ms'.format(data_set.RepetitionTime))
print('The timing of the TE was: {0} ms'.format(data_set.EchoTime))
print('The acquisition matrix was: {0} '.format(data_set.AcquisitionMatrix))
print('The flip angle in degrees was: {0}'.format(data_set.FlipAngle))
print('The acquistion number was: {0} '.format(data_set.AcquisitionNumber))
print('The name of the protocol was: {0}'.format(data_set.ProtocolName))
print('The name of the scan was: {0}'.format(data_set.SeriesDescription))

# Why use the following format to access information in the header?
print('The In-plane Phase Encoding Direction was:', data_set[int('00181312', 16)].value)
print('The Field of View was:', data_set[int('0051100c', 16)].value) 
#alternative approach for doing hexidecimals--
#print(data_set[0x0051100c].value)
#print(data_set[0x00190100a].value) 

print('The Slice Time was: {0}'.format(data_set[0x00191029].value))
# Out:
# The number of TRs collected equals: 103
# The timing of the TR was: 4200 ms
# The timing of the TE was: 89 ms
# The acquisition matrix was: [140, 0, 0, 140]
# The flip angle in degrees was: 90
# The acquistion number was: 24
# The name of the protocol was: dMRI_AP_REVL
# The name of the scan was: dMRI_AP_REVL
# The In-plane Phase Encoding Direction was: COL
# The Field of View was: FoV 2160*2160
# The Slice Time was: [0.0, 2167.50000001, 155.0, 2322.50000001, 310.0, 2477.50000001, 465.0, 2632.50000001, 620.0, 2787.50000001, 774.99999999, 2942.5, 929.99999999, 3097.5, 1084.99999999, 3252.5, 1240.00000002, 3407.5, 1395.00000002, 3562.5, 1550.00000002, 3717.5, 1705.00000002, 3870.0, 1857.50000001, 4024.99999999, 2012.50000001, 0.0, 2167.50000001, 155.0, 2322.50000001, 310.0, 2477.50000001, 465.0, 2632.50000001, 620.0, 2787.50000001, 774.99999999, 2942.5, 929.99999999, 3097.5, 1084.99999999, 3252.5, 1240.00000002, 3407.5, 1395.00000002, 3562.5, 1550.00000002, 3717.5, 1705.00000002, 3870.0, 1857.50000001, 4024.99999999, 2012.50000001, 0.0, 2167.50000001, 155.0, 2322.50000001, 310.0, 2477.50000001, 465.0, 2632.50000001, 620.0, 2787.50000001, 774.99999999, 2942.5, 929.99999999, 3097.5, 1084.99999999, 3252.5, 1240.00000002, 3407.5, 1395.00000002, 3562.5, 1550.00000002, 3717.5, 1705.00000002, 3870.0, 1857.50000001, 4024.99999999, 2012.50000001]

# %%
# How do I find phase encoding direction information?
import nibabel.nicom.csareader as csareader


rowcol_to_niftidim = {'COL': 'i', 'ROW': 'j'}
pedp_to_sign = {0: '-', 1: ''} 

csa_str = data_set[int('00291010', 16)].value
csa_tr = csareader.read(csa_str)
pedp = csa_tr['tags']['PhaseEncodingDirectionPositive']['items'][0]
ij = rowcol_to_niftidim[data_set[int('00181312', 16)].value]
sign = pedp_to_sign[pedp]
print('The phase encoding direction was: {}{}'.format(ij, sign))
# Out:
# The phase encoding direction was: i

# %%
# 6-fMRI_DistortionMap_PA -- fmri field map dicoms


# directories will have to be specific to your computer
base_dir = '/Users/emusser/Documents/GitHub'
proj_dir = '/mattfeld_2020/code'
subj_dir = '/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/'

# with strings I can concatenate them with simple addition lines
data_dir = base_dir + proj_dir + subj_dir


# Here I use glob to grab the dicom files
# Why would I use glob?  What does it give me?
data_files = glob(data_dir + '/*')

# %%
print(data_files)
# Out:
# ['/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-22-npshtr.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-8-54fli8.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-48-q0ywx.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-47-ex4ak1.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-56-heavl0.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-17-1swgu7t.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-50-38737i.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-24-140tdid.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-38-pdhcc5.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-28-18mnwn3.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-4-10denj3.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-23-1shx9t1.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-52-nlu2xn.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-42-1og3h8u.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-11-11gi5z9.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-21-1eol4px.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-1-xxoxou.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-63-1980bcp.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/6-fMRI_DistortionMap_PA/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-6-12-1pq7dxi.dcm', '/U ...

# %%
# Here I am using the python dicom reader to read in a dicom header
# What should go between the square brackets []
data_set = dicom.dcmread(data_files[0])

# %%
print(data_set)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.43.166003.2019061915241161003513836
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# (0002, 0016) Source Application Entity Title     AE: 'AN_MEDCOMNT204'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
# (0008, 0012) Instance Creation Date              DA: '20190619'
# (0008, 0013) Instance Creation Time              TM: '152413.677000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.43.166003.2019061915241161003513836
# (0008, 0020) Study Date                          DA: '20190619'
# (0008, 0021) Series Date                         DA: '20190619'
# (0008, 0022) Acquisition Date                    DA: '20190619'
# (0008, 0023) Content Date                        DA: '20190619'
# (0008, 0030) Study Time                          TM: '150037.662000'
# (0008, 0031) Series Time                         TM: '152413.328000'
# (0008, 0032) Acquisition Time                    TM: '151756.262500'
# (0008, 0033) Content Time                        TM: '152413.677000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'FIU Center For Imaging Science'
# (0008, 0081) Institution Address                 ST: 'SW 8TH ST, OE116 11200,MIAMI,Med-Lab,US,33199'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP166003'
# (0008, 1030) Study Description                   LO: 'Mattfeld_REVL'
# (0008, 103e) Series Description                  LO: 'T1w_MPR_vNav'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1070) Operators' Name                     PN: 'RR'
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163521984993764
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163172628493761
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915162823169893758
#    ---------
# (0010, 0010) Patient's Name                      PN: 'Mattfeld_REVL-000-vCAT-021'
# (0010, 0020) Patient ID                          LO: 'Mattfeld_REVL-000-vCAT-021-S1'
# (0010, 0030) Patient's Birth Date                DA: '19770101'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '042Y'
# (0010, 1020) Patient's Size                      DS: "1.82880366"
# (0010, 1030) Patient's Weight                    DS: "84.3681915522"
# (0010, 4000) Patient Comments                    LT: 'Project: Mattfeld_REVL;Mattfeld_REVL-000-vCAT-021 ; Session: Mattfeld_REVL-000-vCAT-021-S1'
# (0012, 0064)  De-identification Method Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '2'
#    (0008, 0102) Coding Scheme Designator            SH: 'XNAT'
#    (0008, 0103) Coding Scheme Version               SH: '0.1'
#    (0008, 0104) Code Meaning                        LO: 'XNAT Edit Script'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'BRAIN'
# (0018, 0020) Scanning Sequence                   CS: ['GR', 'IR']
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'MP']
# (0018, 0022) Scan Options                        CS: ['IR', 'WE']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'tfl3d1_16ns'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "1.0"
# (0018, 0080) Repetition Time                     DS: "2500.0"
# (0018, 0081) Echo Time                           DS: "2.9"
# (0018, 0082) Inversion Time                      DS: "1070.0"
# (0018, 0083) Number of Averages                  DS: "1.0"
# (0018, 0084) Imaging Frequency                   DS: "123.249149"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3.0"
# (0018, 0089) Number of Phase Encoding Steps      IS: "255"
# (0018, 0091) Echo Train Length                   IS: "1"
# (0018, 0093) Percent Sampling                    DS: "100.0"
# (0018, 0094) Percent Phase Field of View         DS: "100.0"
# (0018, 0095) Pixel Bandwidth                     DS: "240.0"
# (0018, 1000) Device Serial Number                LO: '166003'
# (0018, 1020) Software Versions                   LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'T1w_MPR_vNav'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [0, 256, 256, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: "8.0"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.03557668599229"
# (0018, 1318) dB/dt                               DS: "0.0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0019, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0019, 100b) [SliceMeasurementDuration]          DS: "0.0"
# (0019, 100f) [GradientMode]                      SH: 'Fast'
# (0019, 1011) [FlowCompensation]                  SH: 'No'
# (0019, 1012) [TablePositionOrigin]               SL: [0, 0, -1306]
# (0019, 1013) [ImaAbsTablePosition]               SL: [0, 0, -1306]
# (0019, 1014) [ImaRelTablePosition]               IS: [0, 0, 0]
# (0019, 1015) [SlicePosition_PCS]                 FD: [54.86803865, -151.17331696, 130.23434758]
# (0019, 1017) [SliceResolution]                   DS: "1.0"
# (0019, 1018) [RealDwellTime]                     IS: "8200"
# (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.43.166003.2019061915174069268094190.0.0.0
# (0020, 0010) Study ID                            SH: '1'
# (0020, 0011) Series Number                       IS: "5"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "147"
# (0020, 0032) Image Position (Patient)            DS: [54.868038654327, -151.17331695557, 130.23434758186]
# (0020, 0037) Image Orientation (Patient)         DS: [0, 1, 0, 0, 0, -1]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.43.166003.1.20190619151307196.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "54.868038654327"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: [1, 1]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 1435
# (0028, 1050) Window Center                       DS: "652.0"
# (0028, 1051) Window Width                        DS: "1367.0"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 0012) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0029, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0029, 1009) [CSA Image Header Version]          LO: '20190619'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 11156 elements
# (0029, 1018) [CSA Series Header Type]            CS: 'MR'
# (0029, 1019) [CSA Series Header Version]         LO: '20190619'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 140056 elements
# (0029, 1120) [MedCom History Information]        OB: Array of 308 elements
# (0029, 1260) [Series Workflow Status]            LO: 'com'
# (0040, 0244) Performed Procedure Step Start Date DA: '20190619'
# (0040, 0245) Performed Procedure Step Start Time TM: '150037.732000'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR20190619150037'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Mattfeld_REVL^Mattfeld_REVL'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0051, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0051, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0051, 100a) [Unknown]                           LO: 'TA 00.00'
# (0051, 100b) [AcquisitionMatrixText]             LO: '256*256'
# (0051, 100c) [Unknown]                           LO: 'FoV 256*256'
# (0051, 100d) [Unknown]                           SH: 'SP L54.9'
# (0051, 100e) [Unknown]                           LO: 'Sag'
# (0051, 100f) [CoilString]                        LO: 'HEA;HEP'
# (0051, 1011) [PATModeText]                       LO: 'p2'
# (0051, 1012) [Unknown]                           SH: 'TP 0'
# (0051, 1013) [PositivePCSDirections]             SH: '+LPH'
# (0051, 1016) [Unknown]                           LO: 'p2 M/ND/NORM'
# (0051, 1017) [Unknown]                           SH: 'SL 1.0'
# (0051, 1019) [Unknown]                           LO: 'A1/IR/WE'
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 elements

# %%
# Elements we're interested in
# Repetition Time
# Echo Time
# Acquisition Matrix 
# Flip Angle
# Acquisition Number
# Protocol Name
# Slice times = data_set[0x00191029].value

print('The number of TRs collected equals: {0}'.format(len(data_files)))
print('The timing of the TR was: {0} ms'.format(data_set.RepetitionTime))
print('The timing of the TE was: {0} ms'.format(data_set.EchoTime))
print('The acquisition matrix was: {0} '.format(data_set.AcquisitionMatrix))
print('The flip angle in degrees was: {0}'.format(data_set.FlipAngle))
print('The acquistion number was: {0} '.format(data_set.AcquisitionNumber))
print('The name of the protocol was: {0}'.format(data_set.ProtocolName))
print('The name of the scan was: {0}'.format(data_set.SeriesDescription))

# Why use the following format to access information in the header?
print('The In-plane Phase Encoding Direction was:', data_set[int('00181312', 16)].value)
print('The Field of View was:', data_set[int('0051100c', 16)].value) 
#alternative approach for doing hexidecimals--
#print(data_set[0x0051100c].value)
#slice time info doesn't exist with respect to Number of Images in Mosaic there is no hexidecimal 00191029 in this file or the like...
#print(data_set[0x00190100a].value) 
#print('The Slice Time was: {0}'.format(data_set[0x00191029].value))
# Out:
# The number of TRs collected equals: 66
# The timing of the TR was: 2500 ms
# The timing of the TE was: 2.9 ms
# The acquisition matrix was: [0, 256, 256, 0]
# The flip angle in degrees was: 8
# The acquistion number was: 1
# The name of the protocol was: T1w_MPR_vNav
# The name of the scan was: T1w_MPR_vNav
# The In-plane Phase Encoding Direction was: ROW
# The Field of View was: FoV 256*256

# %%
# How do I find phase encoding direction information?
import nibabel.nicom.csareader as csareader


rowcol_to_niftidim = {'COL': 'i', 'ROW': 'j'}
pedp_to_sign = {0: '-', 1: ''} 

csa_str = data_set[int('00291010', 16)].value
csa_tr = csareader.read(csa_str)
pedp = csa_tr['tags']['PhaseEncodingDirectionPositive']['items'][0]
ij = rowcol_to_niftidim[data_set[int('00181312', 16)].value]
sign = pedp_to_sign[pedp]
print('The phase encoding direction was: {}{}'.format(ij, sign))
# Out:
# The phase encoding direction was: i

# %%
# 7-fMRI_DistortionMap_AP -- fmri field map dicoms opposite phase encode direction


# directories will have to be specific to your computer
base_dir = '/Users/emusser/Documents/GitHub'
proj_dir = '/mattfeld_2020/code'
subj_dir = '/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/'

# with strings I can concatenate them with simple addition lines
data_dir = base_dir + proj_dir + subj_dir


# Here I use glob to grab the dicom files
# Why would I use glob?  What does it give me?
data_files = glob(data_dir + '/*')

# %%
print(data_files)
# Out:
# ['/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-10-1tc8ij0.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-9-6lvn4j.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-4-idhn03.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-65-mxt8yo.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-28-1oa045g.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-46-1enuzwr.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-7-1rfwoyb.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-12-40o5p.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-52-1uaaix9.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-53-5duq89.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-43-13tcl2l.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-30-1auvkef.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-32-1jv34q1.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-37-cn18i2.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-48-1gq58sm.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-19-n03jzs.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-36-66re8v.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-50-z72tko.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/7-fMRI_DistortionMap_AP/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-7-33-1e938em.dcm', '/U ...

# %%
# Here I am using the python dicom reader to read in a dicom header
# What should go between the square brackets []
data_set = dicom.dcmread(data_files[0])

# %%
print(data_set)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.43.166003.2019061915241161003513836
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# (0002, 0016) Source Application Entity Title     AE: 'AN_MEDCOMNT204'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
# (0008, 0012) Instance Creation Date              DA: '20190619'
# (0008, 0013) Instance Creation Time              TM: '152413.677000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.43.166003.2019061915241161003513836
# (0008, 0020) Study Date                          DA: '20190619'
# (0008, 0021) Series Date                         DA: '20190619'
# (0008, 0022) Acquisition Date                    DA: '20190619'
# (0008, 0023) Content Date                        DA: '20190619'
# (0008, 0030) Study Time                          TM: '150037.662000'
# (0008, 0031) Series Time                         TM: '152413.328000'
# (0008, 0032) Acquisition Time                    TM: '151756.262500'
# (0008, 0033) Content Time                        TM: '152413.677000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'FIU Center For Imaging Science'
# (0008, 0081) Institution Address                 ST: 'SW 8TH ST, OE116 11200,MIAMI,Med-Lab,US,33199'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP166003'
# (0008, 1030) Study Description                   LO: 'Mattfeld_REVL'
# (0008, 103e) Series Description                  LO: 'T1w_MPR_vNav'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1070) Operators' Name                     PN: 'RR'
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163521984993764
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163172628493761
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915162823169893758
#    ---------
# (0010, 0010) Patient's Name                      PN: 'Mattfeld_REVL-000-vCAT-021'
# (0010, 0020) Patient ID                          LO: 'Mattfeld_REVL-000-vCAT-021-S1'
# (0010, 0030) Patient's Birth Date                DA: '19770101'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '042Y'
# (0010, 1020) Patient's Size                      DS: "1.82880366"
# (0010, 1030) Patient's Weight                    DS: "84.3681915522"
# (0010, 4000) Patient Comments                    LT: 'Project: Mattfeld_REVL;Mattfeld_REVL-000-vCAT-021 ; Session: Mattfeld_REVL-000-vCAT-021-S1'
# (0012, 0064)  De-identification Method Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '2'
#    (0008, 0102) Coding Scheme Designator            SH: 'XNAT'
#    (0008, 0103) Coding Scheme Version               SH: '0.1'
#    (0008, 0104) Code Meaning                        LO: 'XNAT Edit Script'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'BRAIN'
# (0018, 0020) Scanning Sequence                   CS: ['GR', 'IR']
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'MP']
# (0018, 0022) Scan Options                        CS: ['IR', 'WE']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'tfl3d1_16ns'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "1.0"
# (0018, 0080) Repetition Time                     DS: "2500.0"
# (0018, 0081) Echo Time                           DS: "2.9"
# (0018, 0082) Inversion Time                      DS: "1070.0"
# (0018, 0083) Number of Averages                  DS: "1.0"
# (0018, 0084) Imaging Frequency                   DS: "123.249149"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3.0"
# (0018, 0089) Number of Phase Encoding Steps      IS: "255"
# (0018, 0091) Echo Train Length                   IS: "1"
# (0018, 0093) Percent Sampling                    DS: "100.0"
# (0018, 0094) Percent Phase Field of View         DS: "100.0"
# (0018, 0095) Pixel Bandwidth                     DS: "240.0"
# (0018, 1000) Device Serial Number                LO: '166003'
# (0018, 1020) Software Versions                   LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'T1w_MPR_vNav'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [0, 256, 256, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: "8.0"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.03557668599229"
# (0018, 1318) dB/dt                               DS: "0.0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0019, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0019, 100b) [SliceMeasurementDuration]          DS: "0.0"
# (0019, 100f) [GradientMode]                      SH: 'Fast'
# (0019, 1011) [FlowCompensation]                  SH: 'No'
# (0019, 1012) [TablePositionOrigin]               SL: [0, 0, -1306]
# (0019, 1013) [ImaAbsTablePosition]               SL: [0, 0, -1306]
# (0019, 1014) [ImaRelTablePosition]               IS: [0, 0, 0]
# (0019, 1015) [SlicePosition_PCS]                 FD: [54.86803865, -151.17331696, 130.23434758]
# (0019, 1017) [SliceResolution]                   DS: "1.0"
# (0019, 1018) [RealDwellTime]                     IS: "8200"
# (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.43.166003.2019061915174069268094190.0.0.0
# (0020, 0010) Study ID                            SH: '1'
# (0020, 0011) Series Number                       IS: "5"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "147"
# (0020, 0032) Image Position (Patient)            DS: [54.868038654327, -151.17331695557, 130.23434758186]
# (0020, 0037) Image Orientation (Patient)         DS: [0, 1, 0, 0, 0, -1]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.43.166003.1.20190619151307196.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "54.868038654327"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: [1, 1]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 1435
# (0028, 1050) Window Center                       DS: "652.0"
# (0028, 1051) Window Width                        DS: "1367.0"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 0012) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0029, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0029, 1009) [CSA Image Header Version]          LO: '20190619'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 11156 elements
# (0029, 1018) [CSA Series Header Type]            CS: 'MR'
# (0029, 1019) [CSA Series Header Version]         LO: '20190619'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 140056 elements
# (0029, 1120) [MedCom History Information]        OB: Array of 308 elements
# (0029, 1260) [Series Workflow Status]            LO: 'com'
# (0040, 0244) Performed Procedure Step Start Date DA: '20190619'
# (0040, 0245) Performed Procedure Step Start Time TM: '150037.732000'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR20190619150037'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Mattfeld_REVL^Mattfeld_REVL'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0051, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0051, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0051, 100a) [Unknown]                           LO: 'TA 00.00'
# (0051, 100b) [AcquisitionMatrixText]             LO: '256*256'
# (0051, 100c) [Unknown]                           LO: 'FoV 256*256'
# (0051, 100d) [Unknown]                           SH: 'SP L54.9'
# (0051, 100e) [Unknown]                           LO: 'Sag'
# (0051, 100f) [CoilString]                        LO: 'HEA;HEP'
# (0051, 1011) [PATModeText]                       LO: 'p2'
# (0051, 1012) [Unknown]                           SH: 'TP 0'
# (0051, 1013) [PositivePCSDirections]             SH: '+LPH'
# (0051, 1016) [Unknown]                           LO: 'p2 M/ND/NORM'
# (0051, 1017) [Unknown]                           SH: 'SL 1.0'
# (0051, 1019) [Unknown]                           LO: 'A1/IR/WE'
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 elements

# %%
# Elements we're interested in
# Repetition Time
# Echo Time
# Acquisition Matrix 
# Flip Angle
# Acquisition Number
# Protocol Name
# Slice times = data_set[0x00191029].value

print('The number of TRs collected equals: {0}'.format(len(data_files)))
print('The timing of the TR was: {0} ms'.format(data_set.RepetitionTime))
print('The timing of the TE was: {0} ms'.format(data_set.EchoTime))
print('The acquisition matrix was: {0} '.format(data_set.AcquisitionMatrix))
print('The flip angle in degrees was: {0}'.format(data_set.FlipAngle))
print('The acquistion number was: {0} '.format(data_set.AcquisitionNumber))
print('The name of the protocol was: {0}'.format(data_set.ProtocolName))
print('The name of the scan was: {0}'.format(data_set.SeriesDescription))

# Why use the following format to access information in the header?
print('The In-plane Phase Encoding Direction was:', data_set[int('00181312', 16)].value)
print('The Field of View was:', data_set[int('0051100c', 16)].value) 
#alternative approach for doing hexidecimals--
#print(data_set[0x0051100c].value)
#slice time info doesn't exist with respect to Number of Images in Mosaic there is no hexidecimal 00191029 in this file or the like...
#print(data_set[0x00190100a].value) 
#print('The Slice Time was: {0}'.format(data_set[0x00191029].value))
# Out:
# The number of TRs collected equals: 66
# The timing of the TR was: 2500 ms
# The timing of the TE was: 2.9 ms
# The acquisition matrix was: [0, 256, 256, 0]
# The flip angle in degrees was: 8
# The acquistion number was: 1
# The name of the protocol was: T1w_MPR_vNav
# The name of the scan was: T1w_MPR_vNav
# The In-plane Phase Encoding Direction was: ROW
# The Field of View was: FoV 256*256

# %%
# How do I find phase encoding direction information?
import nibabel.nicom.csareader as csareader


rowcol_to_niftidim = {'COL': 'i', 'ROW': 'j'}
pedp_to_sign = {0: '-', 1: ''} 

csa_str = data_set[int('00291010', 16)].value
csa_tr = csareader.read(csa_str)
pedp = csa_tr['tags']['PhaseEncodingDirectionPositive']['items'][0]
ij = rowcol_to_niftidim[data_set[int('00181312', 16)].value]
sign = pedp_to_sign[pedp]
print('The phase encoding direction was: {}{}'.format(ij, sign))
# Out:
# The phase encoding direction was: i

# %%
# 9-fMRI_REVL_ROI_loc_2 -- fmri localizer dicoms run1

# directories will have to be specific to your computer
base_dir = '/Users/emusser/Documents/GitHub'
proj_dir = '/mattfeld_2020/code'
subj_dir = '/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/'

# with strings I can concatenate them with simple addition lines
data_dir = base_dir + proj_dir + subj_dir


# Here I use glob to grab the dicom files
# Why would I use glob?  What does it give me?
data_files = glob(data_dir + '/*')

# %%
print(data_files)
# Out:
# ['/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-262-1vz2aht.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-97-h63y4e.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-245-4xmdfx.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-18-fmoc4w.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-175-1ppl1cv.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-209-18epjyp.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-213-1ync75p.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-240-1dg6bzb.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-115-1gqgc6d.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-112-6szw20.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-180-1ihifmh.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-203-tyqbe5.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-84-bzccn1.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-167-83ogek.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-15-cv7rzk.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-221-klkfzo.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-190-1p301vw.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-176-16yid51.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/9-fMRI_REVL_ROI_loc_2/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-9-246-6e8uoq.dcm', '/Users/emusser/Documen ...

# %%
# Here I am using the python dicom reader to read in a dicom header
# What should go between the square brackets []
data_set = dicom.dcmread(data_files[0])

# %%
print(data_set)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.43.166003.2019061915241161003513836
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# (0002, 0016) Source Application Entity Title     AE: 'AN_MEDCOMNT204'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
# (0008, 0012) Instance Creation Date              DA: '20190619'
# (0008, 0013) Instance Creation Time              TM: '152413.677000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.43.166003.2019061915241161003513836
# (0008, 0020) Study Date                          DA: '20190619'
# (0008, 0021) Series Date                         DA: '20190619'
# (0008, 0022) Acquisition Date                    DA: '20190619'
# (0008, 0023) Content Date                        DA: '20190619'
# (0008, 0030) Study Time                          TM: '150037.662000'
# (0008, 0031) Series Time                         TM: '152413.328000'
# (0008, 0032) Acquisition Time                    TM: '151756.262500'
# (0008, 0033) Content Time                        TM: '152413.677000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'FIU Center For Imaging Science'
# (0008, 0081) Institution Address                 ST: 'SW 8TH ST, OE116 11200,MIAMI,Med-Lab,US,33199'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP166003'
# (0008, 1030) Study Description                   LO: 'Mattfeld_REVL'
# (0008, 103e) Series Description                  LO: 'T1w_MPR_vNav'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1070) Operators' Name                     PN: 'RR'
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163521984993764
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163172628493761
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915162823169893758
#    ---------
# (0010, 0010) Patient's Name                      PN: 'Mattfeld_REVL-000-vCAT-021'
# (0010, 0020) Patient ID                          LO: 'Mattfeld_REVL-000-vCAT-021-S1'
# (0010, 0030) Patient's Birth Date                DA: '19770101'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '042Y'
# (0010, 1020) Patient's Size                      DS: "1.82880366"
# (0010, 1030) Patient's Weight                    DS: "84.3681915522"
# (0010, 4000) Patient Comments                    LT: 'Project: Mattfeld_REVL;Mattfeld_REVL-000-vCAT-021 ; Session: Mattfeld_REVL-000-vCAT-021-S1'
# (0012, 0064)  De-identification Method Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '2'
#    (0008, 0102) Coding Scheme Designator            SH: 'XNAT'
#    (0008, 0103) Coding Scheme Version               SH: '0.1'
#    (0008, 0104) Code Meaning                        LO: 'XNAT Edit Script'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'BRAIN'
# (0018, 0020) Scanning Sequence                   CS: ['GR', 'IR']
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'MP']
# (0018, 0022) Scan Options                        CS: ['IR', 'WE']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'tfl3d1_16ns'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "1.0"
# (0018, 0080) Repetition Time                     DS: "2500.0"
# (0018, 0081) Echo Time                           DS: "2.9"
# (0018, 0082) Inversion Time                      DS: "1070.0"
# (0018, 0083) Number of Averages                  DS: "1.0"
# (0018, 0084) Imaging Frequency                   DS: "123.249149"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3.0"
# (0018, 0089) Number of Phase Encoding Steps      IS: "255"
# (0018, 0091) Echo Train Length                   IS: "1"
# (0018, 0093) Percent Sampling                    DS: "100.0"
# (0018, 0094) Percent Phase Field of View         DS: "100.0"
# (0018, 0095) Pixel Bandwidth                     DS: "240.0"
# (0018, 1000) Device Serial Number                LO: '166003'
# (0018, 1020) Software Versions                   LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'T1w_MPR_vNav'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [0, 256, 256, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: "8.0"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.03557668599229"
# (0018, 1318) dB/dt                               DS: "0.0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0019, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0019, 100b) [SliceMeasurementDuration]          DS: "0.0"
# (0019, 100f) [GradientMode]                      SH: 'Fast'
# (0019, 1011) [FlowCompensation]                  SH: 'No'
# (0019, 1012) [TablePositionOrigin]               SL: [0, 0, -1306]
# (0019, 1013) [ImaAbsTablePosition]               SL: [0, 0, -1306]
# (0019, 1014) [ImaRelTablePosition]               IS: [0, 0, 0]
# (0019, 1015) [SlicePosition_PCS]                 FD: [54.86803865, -151.17331696, 130.23434758]
# (0019, 1017) [SliceResolution]                   DS: "1.0"
# (0019, 1018) [RealDwellTime]                     IS: "8200"
# (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.43.166003.2019061915174069268094190.0.0.0
# (0020, 0010) Study ID                            SH: '1'
# (0020, 0011) Series Number                       IS: "5"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "147"
# (0020, 0032) Image Position (Patient)            DS: [54.868038654327, -151.17331695557, 130.23434758186]
# (0020, 0037) Image Orientation (Patient)         DS: [0, 1, 0, 0, 0, -1]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.43.166003.1.20190619151307196.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "54.868038654327"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: [1, 1]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 1435
# (0028, 1050) Window Center                       DS: "652.0"
# (0028, 1051) Window Width                        DS: "1367.0"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 0012) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0029, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0029, 1009) [CSA Image Header Version]          LO: '20190619'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 11156 elements
# (0029, 1018) [CSA Series Header Type]            CS: 'MR'
# (0029, 1019) [CSA Series Header Version]         LO: '20190619'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 140056 elements
# (0029, 1120) [MedCom History Information]        OB: Array of 308 elements
# (0029, 1260) [Series Workflow Status]            LO: 'com'
# (0040, 0244) Performed Procedure Step Start Date DA: '20190619'
# (0040, 0245) Performed Procedure Step Start Time TM: '150037.732000'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR20190619150037'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Mattfeld_REVL^Mattfeld_REVL'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0051, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0051, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0051, 100a) [Unknown]                           LO: 'TA 00.00'
# (0051, 100b) [AcquisitionMatrixText]             LO: '256*256'
# (0051, 100c) [Unknown]                           LO: 'FoV 256*256'
# (0051, 100d) [Unknown]                           SH: 'SP L54.9'
# (0051, 100e) [Unknown]                           LO: 'Sag'
# (0051, 100f) [CoilString]                        LO: 'HEA;HEP'
# (0051, 1011) [PATModeText]                       LO: 'p2'
# (0051, 1012) [Unknown]                           SH: 'TP 0'
# (0051, 1013) [PositivePCSDirections]             SH: '+LPH'
# (0051, 1016) [Unknown]                           LO: 'p2 M/ND/NORM'
# (0051, 1017) [Unknown]                           SH: 'SL 1.0'
# (0051, 1019) [Unknown]                           LO: 'A1/IR/WE'
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 elements

# %%
# Elements we're interested in
# Repetition Time
# Echo Time
# Acquisition Matrix 
# Flip Angle
# Acquisition Number
# Protocol Name
# Slice times = data_set[0x00191029].value

print('The number of TRs collected equals: {0}'.format(len(data_files)))
print('The timing of the TR was: {0} ms'.format(data_set.RepetitionTime))
print('The timing of the TE was: {0} ms'.format(data_set.EchoTime))
print('The acquisition matrix was: {0} '.format(data_set.AcquisitionMatrix))
print('The flip angle in degrees was: {0}'.format(data_set.FlipAngle))
print('The acquistion number was: {0} '.format(data_set.AcquisitionNumber))
print('The name of the protocol was: {0}'.format(data_set.ProtocolName))
print('The name of the scan was: {0}'.format(data_set.SeriesDescription))

# Why use the following format to access information in the header?
print('The In-plane Phase Encoding Direction was:', data_set[int('00181312', 16)].value)
print('The Field of View was:', data_set[int('0051100c', 16)].value) 
#alternative approach for doing hexidecimals--print(data_set[0x0051100c].value)
#slice time info doesn't exist with respect to Number of Images in Mosaic there is no hexidecimal 00191029 in this file or the like...print(data_set[0x00190100a].value) 
#print('The Slice Time was: {0}'.format(data_set[0x00191029].value))
# Out:
# The number of TRs collected equals: 304
# The timing of the TR was: 2500 ms
# The timing of the TE was: 2.9 ms
# The acquisition matrix was: [0, 256, 256, 0]
# The flip angle in degrees was: 8
# The acquistion number was: 1
# The name of the protocol was: T1w_MPR_vNav
# The name of the scan was: T1w_MPR_vNav
# The In-plane Phase Encoding Direction was: ROW
# The Field of View was: FoV 256*256

# %%
# How do I find phase encoding direction information?
import nibabel.nicom.csareader as csareader


rowcol_to_niftidim = {'COL': 'i', 'ROW': 'j'}
pedp_to_sign = {0: '-', 1: ''} 

csa_str = data_set[int('00291010', 16)].value
csa_tr = csareader.read(csa_str)
pedp = csa_tr['tags']['PhaseEncodingDirectionPositive']['items'][0]
ij = rowcol_to_niftidim[data_set[int('00181312', 16)].value]
sign = pedp_to_sign[pedp]
print('The phase encoding direction was: {}{}'.format(ij, sign))
# Out:
# The phase encoding direction was: i

# %%
# 10-fMRI_REVL_Study_1 -- fmri task dicoms run1
# directories will have to be specific to your computer
base_dir = '/Users/emusser/Documents/GitHub'
proj_dir = '/mattfeld_2020/code'
subj_dir = '/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/'

# with strings I can concatenate them with simple addition lines
data_dir = base_dir + proj_dir + subj_dir


# Here I use glob to grab the dicom files
# Why would I use glob?  What does it give me?
data_files = glob(data_dir + '/*')

# %%
print(data_files)
# Out:
# ['/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-6-1j8kpi7.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-292-x6mb7t.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-288-v6og2m.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-33-kymxgv.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-286-1krvknx.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-172-rwngu3.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-285-4p90au.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-287-8mzh2u.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-246-urarwv.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-259-veibuc.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-272-fcwgs1.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-148-2j1sm2.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-293-14l4npm.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-311-171r4ob.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-213-cnqpny.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-206-1jg1g42.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-162-5wvx7n.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-214-ccji6w.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/10-fMRI_REVL_Study_1/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-10-9-3ynt7q.dcm', '/Users/emusser/Documents/Gi ...

# %%
# Here I am using the python dicom reader to read in a dicom header
# What should go between the square brackets []
data_set = dicom.dcmread(data_files[0])

# %%
print(data_set)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.43.166003.2019061915480017886637273
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# (0002, 0016) Source Application Entity Title     AE: 'AN_MEDCOMNT204'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC']
# (0008, 0012) Instance Creation Date              DA: '20190619'
# (0008, 0013) Instance Creation Time              TM: '154835.406000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.43.166003.2019061915480017886637273
# (0008, 0020) Study Date                          DA: '20190619'
# (0008, 0021) Series Date                         DA: '20190619'
# (0008, 0022) Acquisition Date                    DA: '20190619'
# (0008, 0023) Content Date                        DA: '20190619'
# (0008, 0030) Study Time                          TM: '150037.662000'
# (0008, 0031) Series Time                         TM: '154835.373000'
# (0008, 0032) Acquisition Time                    TM: '154758.855000'
# (0008, 0033) Content Time                        TM: '154835.406000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'FIU Center For Imaging Science'
# (0008, 0081) Institution Address                 ST: 'SW 8TH ST, OE116 11200,MIAMI,Med-Lab,US,33199'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP166003'
# (0008, 1030) Study Description                   LO: 'Mattfeld_REVL'
# (0008, 103e) Series Description                  LO: 'fMRI_REVL_Study_1'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1070) Operators' Name                     PN: 'RR'
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915162823169893758
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163521984993764
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163172628493761
#    ---------
# (0008, 2112)  Source Image Sequence   66 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475978696737076
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475980084437079
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475982326337084
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475982748237087
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475983123537090
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475983665437093
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475984045737096
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475984494237099
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475984931437102
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475985325037103
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475986843337106
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475988925537109
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475989382037114
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475989789937117
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475990173037119
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475990606137123
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475991008637124
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475991806737127
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475992278037132
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475992661937133
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475993066337136
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475993524137139
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475994002237142
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475994586337145
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475995060637148
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475995667937151
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475996954737156
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475997350637159
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475997775837162
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475998229437165
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475998514037166
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475999147237171
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475999383237172
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915475999903837175
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.20190619154800372437178
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.20190619154800826037183
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548001226137184
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548001692537187
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548002204437190
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548002849137193
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548003444337196
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548004052137199
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548004664237202
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548005327437205
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548005806137208
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548006362337211
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548007010237214
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548007750737217
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548008195137220
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548008716137224
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548009172337227
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191548009617837230
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480010154437233
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480010818137236
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480011337937239
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480011998437242
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480012603537245
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480013187037248
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480013665037251
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480014205237254
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480014823537257
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480015459337260
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480015996837263
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480016401237266
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480016976337269
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915480017522037272
#    ---------
# (0010, 0010) Patient's Name                      PN: 'Mattfeld_REVL-000-vCAT-021'
# (0010, 0020) Patient ID                          LO: 'Mattfeld_REVL-000-vCAT-021-S1'
# (0010, 0030) Patient's Birth Date                DA: '19770101'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '042Y'
# (0010, 1020) Patient's Size                      DS: "1.82880366"
# (0010, 1030) Patient's Weight                    DS: "84.3681915522"
# (0010, 4000) Patient Comments                    LT: 'Project: Mattfeld_REVL;Mattfeld_REVL-000-vCAT-021 ; Session: Mattfeld_REVL-000-vCAT-021-S1'
# (0012, 0064)  De-identification Method Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '2'
#    (0008, 0102) Coding Scheme Designator            SH: 'XNAT'
#    (0008, 0103) Coding Scheme Version               SH: '0.1'
#    (0008, 0104) Code Meaning                        LO: 'XNAT Edit Script'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'BRAIN'
# (0018, 0020) Scanning Sequence                   CS: 'EP'
# (0018, 0021) Sequence Variant                    CS: 'SK'
# (0018, 0022) Scan Options                        CS: 'FS'
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: 'epfid2d1_90'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "2.0"
# (0018, 0080) Repetition Time                     DS: "1760.0"
# (0018, 0081) Echo Time                           DS: "35.0"
# (0018, 0083) Number of Averages                  DS: "1.0"
# (0018, 0084) Imaging Frequency                   DS: "123.249153"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3.0"
# (0018, 0088) Spacing Between Slices              DS: "2.0000000381972"
# (0018, 0089) Number of Phase Encoding Steps      IS: "90"
# (0018, 0091) Echo Train Length                   IS: "90"
# (0018, 0093) Percent Sampling                    DS: "90.0"
# (0018, 0094) Percent Phase Field of View         DS: "100.0"
# (0018, 0095) Pixel Bandwidth                     DS: "2780.0"
# (0018, 1000) Device Serial Number                LO: '166003'
# (0018, 1020) Software Versions                   LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'fMRI_REVL_Study_1'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [100, 0, 0, 90]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "52.0"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.04013631633872"
# (0018, 1318) dB/dt                               DS: "0.0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0019, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0019, 100a) [NumberOfImagesInMosaic]            US: 66
# (0019, 100b) [SliceMeasurementDuration]          DS: "630000.0"
# (0019, 100f) [GradientMode]                      SH: 'Fast*'
# (0019, 1011) [FlowCompensation]                  SH: 'No'
# (0019, 1012) [TablePositionOrigin]               SL: [0, 0, -1306]
# (0019, 1013) [ImaAbsTablePosition]               SL: [0, 0, -1306]
# (0019, 1014) [ImaRelTablePosition]               IS: [0, 0, 0]
# (0019, 1015) [SlicePosition_PCS]                 FD: [-901.7710135, -821.05534252, 406.27493547]
# (0019, 1016) [TimeAfterStart]                    DS: "15.315"
# (0019, 1017) [SliceResolution]                   DS: "1.0"
# (0019, 1018) [RealDwellTime]                     IS: "1800"
# (0019, 1028) [BandwidthPerPixelPhaseEncode]      FD: 16.393
# (0019, 1029) [MosaicRefAcqTimes]                 FD: Array of 66 elements
# (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.43.166003.2019061915471170406436072.0.0.0
# (0020, 0010) Study ID                            SH: '1'
# (0020, 0011) Series Number                       IS: "10"
# (0020, 0012) Acquisition Number                  IS: "6"
# (0020, 0013) Instance Number                     IS: "6"
# (0020, 0032) Image Position (Patient)            DS: [-901.77101349831, -821.0553425197, 406.27493547262]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 0.86602540210929, -0.5000000029014]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.43.166003.1.20190619151307196.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-58.683259282487"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 900
# (0028, 0011) Columns                             US: 900
# (0028, 0030) Pixel Spacing                       DS: [2, 2]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 1350
# (0028, 1050) Window Center                       DS: "374.0"
# (0028, 1051) Window Width                        DS: "814.0"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 0012) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0029, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0029, 1009) [CSA Image Header Version]          LO: '20190619'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 13572 elements
# (0029, 1018) [CSA Series Header Type]            CS: 'MR'
# (0029, 1019) [CSA Series Header Version]         LO: '20190619'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 147536 elements
# (0029, 1120) [MedCom History Information]        OB: Array of 308 elements
# (0029, 1260) [Series Workflow Status]            LO: 'com'
# (0040, 0244) Performed Procedure Step Start Date DA: '20190619'
# (0040, 0245) Performed Procedure Step Start Time TM: '150037.732000'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR20190619150037'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Mattfeld_REVL^Mattfeld_REVL'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0051, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0051, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0051, 100a) [Unknown]                           LO: 'TA 10:30'
# (0051, 100b) [AcquisitionMatrixText]             LO: '90*100'
# (0051, 100c) [Unknown]                           LO: 'FoV 1800*1800'
# (0051, 100e) [Unknown]                           LO: 'Tra>Cor(-30.0)'
# (0051, 100f) [CoilString]                        LO: 'HEA;HEP'
# (0051, 1011) [PATModeText]                       LO: 's3'
# (0051, 1012) [Unknown]                           SH: 'TP 0'
# (0051, 1013) [PositivePCSDirections]             SH: '+LPH'
# (0051, 1016) [Unknown]                           LO: 's3 M/ND/MOSAIC'
# (0051, 1017) [Unknown]                           SH: 'SL 2.0'
# (0051, 1019) [Unknown]                           LO: 'A1/FS'
# (7fe0, 0010) Pixel Data                          OW: Array of 1620000 elements

# %%
# Elements we're interested in
# Repetition Time
# Echo Time
# Acquisition Matrix 
# Flip Angle
# Acquisition Number
# Protocol Name
# Slice times = data_set[0x00191029].value

print('The number of TRs collected equals: {0}'.format(len(data_files)))
print('The timing of the TR was: {0} ms'.format(data_set.RepetitionTime))
print('The timing of the TE was: {0} ms'.format(data_set.EchoTime))
print('The acquisition matrix was: {0} '.format(data_set.AcquisitionMatrix))
print('The flip angle in degrees was: {0}'.format(data_set.FlipAngle))
print('The acquistion number was: {0} '.format(data_set.AcquisitionNumber))
print('The name of the protocol was: {0}'.format(data_set.ProtocolName))
print('The name of the scan was: {0}'.format(data_set.SeriesDescription))

# Why use the following format to access information in the header?
print('The In-plane Phase Encoding Direction was:', data_set[int('00181312', 16)].value)
print('The Field of View was:', data_set[int('0051100c', 16)].value) 
#alternative approach for doing hexidecimals--
#print(data_set[0x0051100c].value)
#slice time info doesn't exist with respect to Number of Images in Mosaic there is no hexidecimal 00191029 in this file or the like...

print('The Slice Time was: {0}'.format(data_set[0x00191029].value))
# Out:
# The number of TRs collected equals: 103
# The timing of the TR was: 4200 ms
# The timing of the TE was: 89 ms
# The acquisition matrix was: [140, 0, 0, 140]
# The flip angle in degrees was: 90
# The acquistion number was: 24
# The name of the protocol was: dMRI_AP_REVL
# The name of the scan was: dMRI_AP_REVL
# The In-plane Phase Encoding Direction was: COL
# The Field of View was: FoV 2160*2160
# The Slice Time was: [0.0, 2167.50000001, 155.0, 2322.50000001, 310.0, 2477.50000001, 465.0, 2632.50000001, 620.0, 2787.50000001, 774.99999999, 2942.5, 929.99999999, 3097.5, 1084.99999999, 3252.5, 1240.00000002, 3407.5, 1395.00000002, 3562.5, 1550.00000002, 3717.5, 1705.00000002, 3870.0, 1857.50000001, 4024.99999999, 2012.50000001, 0.0, 2167.50000001, 155.0, 2322.50000001, 310.0, 2477.50000001, 465.0, 2632.50000001, 620.0, 2787.50000001, 774.99999999, 2942.5, 929.99999999, 3097.5, 1084.99999999, 3252.5, 1240.00000002, 3407.5, 1395.00000002, 3562.5, 1550.00000002, 3717.5, 1705.00000002, 3870.0, 1857.50000001, 4024.99999999, 2012.50000001, 0.0, 2167.50000001, 155.0, 2322.50000001, 310.0, 2477.50000001, 465.0, 2632.50000001, 620.0, 2787.50000001, 774.99999999, 2942.5, 929.99999999, 3097.5, 1084.99999999, 3252.5, 1240.00000002, 3407.5, 1395.00000002, 3562.5, 1550.00000002, 3717.5, 1705.00000002, 3870.0, 1857.50000001, 4024.99999999, 2012.50000001]

# %%
# How do I find phase encoding direction information?
import nibabel.nicom.csareader as csareader


rowcol_to_niftidim = {'COL': 'i', 'ROW': 'j'}
pedp_to_sign = {0: '-', 1: ''} 

csa_str = data_set[int('00291010', 16)].value
csa_tr = csareader.read(csa_str)
pedp = csa_tr['tags']['PhaseEncodingDirectionPositive']['items'][0]
ij = rowcol_to_niftidim[data_set[int('00181312', 16)].value]
sign = pedp_to_sign[pedp]
print('The phase encoding direction was: {}{}'.format(ij, sign))
# Out:
# The phase encoding direction was: i

# %%
# 14-dMRI_DistortionMap_AP_dMRI_REVL -- dwi field map dicoms


# directories will have to be specific to your computer
base_dir = '/Users/emusser/Documents/GitHub'
proj_dir = '/mattfeld_2020/code'
subj_dir = '/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/'

# with strings I can concatenate them with simple addition lines
data_dir = base_dir + proj_dir + subj_dir


# Here I use glob to grab the dicom files
# Why would I use glob?  What does it give me?
data_files = glob(data_dir + '/*')

# %%
print(data_files)
# Out:
# ['/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-15-1knyrsc.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-22-1hu2c4z.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-76-nhe7x6.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-26-1ucke1n.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-39-a5jljq.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-24-1gvkgaa.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-6-b8bstj.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-72-2qaqkj.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-4-1lpwj4r.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-62-vf9f71.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-51-1e85fh2.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-44-1e4n5jt.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-2-pjg254.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-68-85k42o.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-12-g27fmz.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-17-1gp8dnt.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-58-1hbzmr.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/14-dMRI_DistortionMap_AP_dMRI_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-14-9-1wv1czw.dcm' ...

# %%
# Here I am using the python dicom reader to read in a dicom header
# What should go between the square brackets []
data_set = dicom.dcmread(data_files[0])

# %%
print(data_set)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.43.166003.2019061916314440169621081
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# (0002, 0016) Source Application Entity Title     AE: 'AN_MEDCOMNT204'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'DIFFUSION', 'NONE', 'ND']
# (0008, 0012) Instance Creation Date              DA: '20190619'
# (0008, 0013) Instance Creation Time              TM: '163154.802000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.43.166003.2019061916314440169621081
# (0008, 0020) Study Date                          DA: '20190619'
# (0008, 0021) Series Date                         DA: '20190619'
# (0008, 0022) Acquisition Date                    DA: '20190619'
# (0008, 0023) Content Date                        DA: '20190619'
# (0008, 0030) Study Time                          TM: '150037.662000'
# (0008, 0031) Series Time                         TM: '163154.783000'
# (0008, 0032) Acquisition Time                    TM: '163143.045000'
# (0008, 0033) Content Time                        TM: '163154.802000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'FIU Center For Imaging Science'
# (0008, 0081) Institution Address                 ST: 'SW 8TH ST, OE116 11200,MIAMI,Med-Lab,US,33199'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP166003'
# (0008, 1030) Study Description                   LO: 'Mattfeld_REVL'
# (0008, 103e) Series Description                  LO: 'dMRI_DistortionMap_AP_dMRI_REVL'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1070) Operators' Name                     PN: 'RR'
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163521984993764
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191524106394213628
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163172628493761
#    ---------
# (0010, 0010) Patient's Name                      PN: 'Mattfeld_REVL-000-vCAT-021'
# (0010, 0020) Patient ID                          LO: 'Mattfeld_REVL-000-vCAT-021-S1'
# (0010, 0030) Patient's Birth Date                DA: '19770101'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '042Y'
# (0010, 1020) Patient's Size                      DS: "1.82880366"
# (0010, 1030) Patient's Weight                    DS: "84.3681915522"
# (0010, 4000) Patient Comments                    LT: 'Project: Mattfeld_REVL;Mattfeld_REVL-000-vCAT-021 ; Session: Mattfeld_REVL-000-vCAT-021-S1'
# (0012, 0064)  De-identification Method Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '2'
#    (0008, 0102) Coding Scheme Designator            SH: 'XNAT'
#    (0008, 0103) Coding Scheme Version               SH: '0.1'
#    (0008, 0104) Code Meaning                        LO: 'XNAT Edit Script'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'BRAIN'
# (0018, 0020) Scanning Sequence                   CS: 'EP'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP']
# (0018, 0022) Scan Options                        CS: ['PFP', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: 'ep_b0'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "1.7000000476837"
# (0018, 0080) Repetition Time                     DS: "12600.0"
# (0018, 0081) Echo Time                           DS: "89.0"
# (0018, 0083) Number of Averages                  DS: "1.0"
# (0018, 0084) Imaging Frequency                   DS: "123.249172"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3.0"
# (0018, 0088) Spacing Between Slices              DS: "1.7"
# (0018, 0089) Number of Phase Encoding Steps      IS: "105"
# (0018, 0091) Echo Train Length                   IS: "105"
# (0018, 0093) Percent Sampling                    DS: "100.0"
# (0018, 0094) Percent Phase Field of View         DS: "100.0"
# (0018, 0095) Pixel Bandwidth                     DS: "1700.0"
# (0018, 1000) Device Serial Number                LO: '166003'
# (0018, 1020) Software Versions                   LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'dMRI_DistortionMap_AP_dMRI_REVL'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [140, 0, 0, 140]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "90.0"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.12464067267085"
# (0018, 1318) dB/dt                               DS: "0.0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0019, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0019, 100b) [SliceMeasurementDuration]          DS: "25000.0"
# (0019, 100c) [B_value]                           IS: "0"
# (0019, 100d) [DiffusionDirectionality]           CS: 'NONE'
# (0019, 100f) [GradientMode]                      SH: ''
# (0019, 1011) [FlowCompensation]                  SH: 'No'
# (0019, 1012) [TablePositionOrigin]               SL: [0, 0, -1306]
# (0019, 1013) [ImaAbsTablePosition]               SL: [0, 0, -1306]
# (0019, 1014) [ImaRelTablePosition]               IS: [0, 0, 0]
# (0019, 1015) [SlicePosition_PCS]                 FD: [-122.89651847, -132.47941995, -40.39854813]
# (0019, 1016) [TimeAfterStart]                    DS: "1.0875"
# (0019, 1017) [SliceResolution]                   DS: "1.0"
# (0019, 1018) [RealDwellTime]                     IS: "2100"
# (0019, 1028) [BandwidthPerPixelPhaseEncode]      FD: 10.352
# (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.43.166003.2019061916312656812520996.0.0.0
# (0020, 0010) Study ID                            SH: '1'
# (0020, 0011) Series Number                       IS: "14"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "15"
# (0020, 0032) Image Position (Patient)            DS: [-122.89651846886, -132.47941994667, -40.398548126221]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.43.166003.1.20190619151307196.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-40.398548126221"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 140
# (0028, 0011) Columns                             US: 140
# (0028, 0030) Pixel Spacing                       DS: [1.7142857313156, 1.7142857313156]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 1689
# (0028, 1050) Window Center                       DS: "393.0"
# (0028, 1051) Window Width                        DS: "884.0"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 0012) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0029, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0029, 1009) [CSA Image Header Version]          LO: '20190619'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 11688 elements
# (0029, 1018) [CSA Series Header Type]            CS: 'MR'
# (0029, 1019) [CSA Series Header Version]         LO: '20190619'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 166604 elements
# (0029, 1120) [MedCom History Information]        OB: Array of 308 elements
# (0029, 1260) [Series Workflow Status]            LO: 'com'
# (0040, 0244) Performed Procedure Step Start Date DA: '20190619'
# (0040, 0245) Performed Procedure Step Start Time TM: '150037.732000'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR20190619150037'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Mattfeld_REVL^Mattfeld_REVL'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0051, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0051, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0051, 100a) [Unknown]                           LO: 'TA 25.00'
# (0051, 100b) [AcquisitionMatrixText]             LO: '140p*140'
# (0051, 100c) [Unknown]                           LO: 'FoV 240*240'
# (0051, 100d) [Unknown]                           SH: 'SP F40.4'
# (0051, 100e) [Unknown]                           LO: 'Tra'
# (0051, 100f) [CoilString]                        LO: 'HEA;HEP'
# (0051, 1012) [Unknown]                           SH: 'TP 0'
# (0051, 1013) [PositivePCSDirections]             SH: '+LPH'
# (0051, 1016) [Unknown]                           LO: 'DIFFUSION/NONE/ND'
# (0051, 1017) [Unknown]                           SH: 'SL 1.7'
# (0051, 1019) [Unknown]                           LO: 'A1/PFP/FS'
# (7fe0, 0010) Pixel Data                          OW: Array of 39200 elements

# %%
# Elements we're interested in
# Repetition Time
# Echo Time
# Acquisition Matrix 
# Flip Angle
# Acquisition Number
# Protocol Name
# Slice times = data_set[0x00191029].value

print('The number of TRs collected equals: {0}'.format(len(data_files)))
print('The timing of the TR was: {0} ms'.format(data_set.RepetitionTime))
print('The timing of the TE was: {0} ms'.format(data_set.EchoTime))
print('The acquisition matrix was: {0} '.format(data_set.AcquisitionMatrix))
print('The flip angle in degrees was: {0}'.format(data_set.FlipAngle))
print('The acquistion number was: {0} '.format(data_set.AcquisitionNumber))
print('The name of the protocol was: {0}'.format(data_set.ProtocolName))
print('The name of the scan was: {0}'.format(data_set.SeriesDescription))

# Why use the following format to access information in the header?
print('The In-plane Phase Encoding Direction was:', data_set[int('00181312', 16)].value)
print('The Field of View was:', data_set[int('0051100c', 16)].value) 
#alternative approach for doing hexidecimals--
#print(data_set[0x0051100c].value)
#slice time info doesn't exist with respect to Number of Images in Mosaic there is no hexidecimal 00191029 in this file or the like...
#print(data_set[0x00190100a].value) 
#print('The Slice Time was: {0}'.format(data_set[0x00191029].value))
# Out:
# The number of TRs collected equals: 81
# The timing of the TR was: 12600 ms
# The timing of the TE was: 89 ms
# The acquisition matrix was: [140, 0, 0, 140]
# The flip angle in degrees was: 90
# The acquistion number was: 1
# The name of the protocol was: dMRI_DistortionMap_AP_dMRI_REVL
# The name of the scan was: dMRI_DistortionMap_AP_dMRI_REVL
# The In-plane Phase Encoding Direction was: COL
# The Field of View was: FoV 240*240

# %%
# How do I find phase encoding direction information?
import nibabel.nicom.csareader as csareader


rowcol_to_niftidim = {'COL': 'i', 'ROW': 'j'}
pedp_to_sign = {0: '-', 1: ''} 

csa_str = data_set[int('00291010', 16)].value
csa_tr = csareader.read(csa_str)
pedp = csa_tr['tags']['PhaseEncodingDirectionPositive']['items'][0]
ij = rowcol_to_niftidim[data_set[int('00181312', 16)].value]
sign = pedp_to_sign[pedp]
print('The phase encoding direction was: {}{}'.format(ij, sign))
# Out:
# The phase encoding direction was: i

# %%
# 16-dMRI_AP_REVL -- diffusion weighted dicoms

# directories will have to be specific to your computer
base_dir = '/Users/emusser/Documents/GitHub'
proj_dir = '/mattfeld_2020/code'
subj_dir = '/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/'

# with strings I can concatenate them with simple addition lines
data_dir = base_dir + proj_dir + subj_dir


# Here I use glob to grab the dicom files
# Why would I use glob?  What does it give me?
data_files = glob(data_dir + '/*')

# %%
print(data_files)
# Out:
# ['/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-24-zbt5ua.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-60-sl4x5r.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-88-1dcaptf.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-47-1ehi73i.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-49-15lpik7.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-51-1uaapv5.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-8-1o39pmt.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-99-1ssew90.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-103-qfn87d.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-1-1knqzcr.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-17-1pbw48e.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-7-1lgxh09.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-3-10orrhb.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-98-1s3ild3.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-15-e8uzsz.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-90-1ci7qec.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-40-19b5el9.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-2-1s7hwxj.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017-16-33-tl1qmp.dcm', '/Users/emusser/Documents/GitHub/mattfeld_2020/code/Mattfeld_REVL-000-vCAT-021-S1/scans/16-dMRI_AP_REVL/resources/DICOM/files/1.3.12 ...

# %%
# Here I am using the python dicom reader to read in a dicom header
# What should go between the square brackets []
data_set = dicom.dcmread(data_files[0])

# %%
print(data_set)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.43.166003.2019061916344247531431643
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# (0002, 0016) Source Application Entity Title     AE: 'AN_MEDCOMNT204'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'DIFFUSION', 'NONE', 'ND', 'MOSAIC']
# (0008, 0012) Instance Creation Date              DA: '20190619'
# (0008, 0013) Instance Creation Time              TM: '163615.376000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.43.166003.2019061916344247531431643
# (0008, 0020) Study Date                          DA: '20190619'
# (0008, 0021) Series Date                         DA: '20190619'
# (0008, 0022) Acquisition Date                    DA: '20190619'
# (0008, 0023) Content Date                        DA: '20190619'
# (0008, 0030) Study Time                          TM: '150037.662000'
# (0008, 0031) Series Time                         TM: '163435.373000'
# (0008, 0032) Acquisition Time                    TM: '163437.025000'
# (0008, 0033) Content Time                        TM: '163615.376000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'FIU Center For Imaging Science'
# (0008, 0081) Institution Address                 ST: 'SW 8TH ST, OE116 11200,MIAMI,Med-Lab,US,33199'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'AWP166003'
# (0008, 1030) Study Description                   LO: 'Mattfeld_REVL'
# (0008, 103e) Series Description                  LO: 'dMRI_AP_REVL'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1070) Operators' Name                     PN: 'RR'
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915162823169893758
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163521984993764
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061915163172628493761
#    ---------
# (0008, 2112)  Source Image Sequence   81 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344183761731245
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344184738831249
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344185674431252
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344194050631265
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344194986831270
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344196173131277
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344196571531282
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344197352831287
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344198462231292
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344199693731299
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.20190619163442203731304
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.20190619163442933831309
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634422505031318
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634423017331324
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634423349831326
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634423768931331
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634424246531336
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634425740131347
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634425784231348
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634426585931355
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634426797731359
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634427110731361
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634427819031368
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634428331531371
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634429077331376
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634429475731381
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.201906191634429911131386
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344210595031391
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344212589031406
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344212623231407
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344212649631408
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344212676431409
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344213335631414
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344213961931421
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344214753131426
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344215262631431
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344216685331442
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344216718031443
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344216921431446
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344217782231451
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344218271231456
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344219093131461
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344219174031462
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344220070231467
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344221007431472
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344221044231473
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344221754831476
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344222130431479
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344223857631484
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344226505831495
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344228484231506
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344229284231511
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344229837731516
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344231268731529
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344231302631530
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344231462731533
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344232062531538
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344232456331541
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344233060031548
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344233878331555
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344234047131556
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344234523731561
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344235034931566
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344235757931571
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344235989031574
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344236511031577
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344237516731586
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344237715531587
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344238340731592
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344239160031597
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344240218831602
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344240650531607
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344241538631612
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344242700531621
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344242856131622
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344243769831627
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344244487331630
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344245306631633
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344246252431636
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344246828731639
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.43.166003.2019061916344247500631642
#    ---------
# (0010, 0010) Patient's Name                      PN: 'Mattfeld_REVL-000-vCAT-021'
# (0010, 0020) Patient ID                          LO: 'Mattfeld_REVL-000-vCAT-021-S1'
# (0010, 0030) Patient's Birth Date                DA: '19770101'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '042Y'
# (0010, 1020) Patient's Size                      DS: "1.82880366"
# (0010, 1030) Patient's Weight                    DS: "84.3681915522"
# (0010, 4000) Patient Comments                    LT: 'Project: Mattfeld_REVL;Mattfeld_REVL-000-vCAT-021 ; Session: Mattfeld_REVL-000-vCAT-021-S1'
# (0012, 0064)  De-identification Method Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '2'
#    (0008, 0102) Coding Scheme Designator            SH: 'XNAT'
#    (0008, 0103) Coding Scheme Version               SH: '0.1'
#    (0008, 0104) Code Meaning                        LO: 'XNAT Edit Script'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'BRAIN'
# (0018, 0020) Scanning Sequence                   CS: 'EP'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP']
# (0018, 0022) Scan Options                        CS: ['PFP', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: 'ep_b3000#23'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "1.7000000476837"
# (0018, 0080) Repetition Time                     DS: "4200.0"
# (0018, 0081) Echo Time                           DS: "89.0"
# (0018, 0083) Number of Averages                  DS: "1.0"
# (0018, 0084) Imaging Frequency                   DS: "123.249172"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3.0"
# (0018, 0088) Spacing Between Slices              DS: "1.7"
# (0018, 0089) Number of Phase Encoding Steps      IS: "105"
# (0018, 0091) Echo Train Length                   IS: "105"
# (0018, 0093) Percent Sampling                    DS: "100.0"
# (0018, 0094) Percent Phase Field of View         DS: "100.0"
# (0018, 0095) Pixel Bandwidth                     DS: "1700.0"
# (0018, 1000) Device Serial Number                LO: '166003'
# (0018, 1020) Software Versions                   LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'dMRI_AP_REVL'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [140, 0, 0, 140]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "90.0"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.23810409618705"
# (0018, 1318) dB/dt                               DS: "0.0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0019, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0019, 100a) [NumberOfImagesInMosaic]            US: 81
# (0019, 100b) [SliceMeasurementDuration]          DS: "449000.0"
# (0019, 100c) [B_value]                           IS: "3000"
# (0019, 100d) [DiffusionDirectionality]           CS: 'DIRECTIONAL'
# (0019, 100e) [DiffusionGradientDirection]        FD: [0.63655597, -0.09850488, -0.76491398]
# (0019, 100f) [GradientMode]                      SH: ''
# (0019, 1011) [FlowCompensation]                  SH: 'No'
# (0019, 1012) [TablePositionOrigin]               SL: [0, 0, -1306]
# (0019, 1013) [ImaAbsTablePosition]               SL: [0, 0, -1306]
# (0019, 1014) [ImaRelTablePosition]               IS: [0, 0, 0]
# (0019, 1015) [SlicePosition_PCS]                 FD: [-1082.89652801, -1092.47942948, -64.19854736]
# (0019, 1016) [TimeAfterStart]                    DS: "113.155"
# (0019, 1017) [SliceResolution]                   DS: "1.0"
# (0019, 1018) [RealDwellTime]                     IS: "2100"
# (0019, 1027) [B_matrix]                          FD: [1221.0, -189.0, -1467.0, 29.0, 227.0, 1763.0]
# (0019, 1028) [BandwidthPerPixelPhaseEncode]      FD: 10.352
# (0019, 1029) [MosaicRefAcqTimes]                 FD: Array of 81 elements
# (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.2.43.166003.30000019061912563618000000017
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.43.166003.2019061916322487110321854.0.0.0
# (0020, 0010) Study ID                            SH: '1'
# (0020, 0011) Series Number                       IS: "16"
# (0020, 0012) Acquisition Number                  IS: "24"
# (0020, 0013) Instance Number                     IS: "24"
# (0020, 0032) Image Position (Patient)            DS: [-1082.8965280056, -1092.4794294834, -64.198547363281]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.43.166003.1.20190619151307196.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-64.198547363281"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1260
# (0028, 0011) Columns                             US: 1260
# (0028, 0030) Pixel Spacing                       DS: [1.7142857313156, 1.7142857313156]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 489
# (0028, 1050) Window Center                       DS: "119.0"
# (0028, 1051) Window Width                        DS: "303.0"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 0012) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0029, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0029, 1009) [CSA Image Header Version]          LO: '20190619'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 15260 elements
# (0029, 1018) [CSA Series Header Type]            CS: 'MR'
# (0029, 1019) [CSA Series Header Version]         LO: '20190619'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 166896 elements
# (0029, 1120) [MedCom History Information]        OB: Array of 308 elements
# (0029, 1260) [Series Workflow Status]            LO: 'com'
# (0040, 0244) Performed Procedure Step Start Date DA: '20190619'
# (0040, 0245) Performed Procedure Step Start Time TM: '150037.732000'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR20190619150037'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Mattfeld_REVL^Mattfeld_REVL'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0051, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0051, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0051, 100a) [Unknown]                           LO: 'TA 07:29'
# (0051, 100b) [AcquisitionMatrixText]             LO: '140p*140'
# (0051, 100c) [Unknown]                           LO: 'FoV 2160*2160'
# (0051, 100e) [Unknown]                           LO: 'Tra'
# (0051, 100f) [CoilString]                        LO: 'HEA;HEP'
# (0051, 1011) [PATModeText]                       LO: 's3'
# (0051, 1012) [Unknown]                           SH: 'TP 0'
# (0051, 1013) [PositivePCSDirections]             SH: '+LPH'
# (0051, 1016) [Unknown]                           LO: 's3 DIFFUSION/NONE/ND/MOSAIC'
# (0051, 1017) [Unknown]                           SH: 'SL 1.7'
# (0051, 1019) [Unknown]                           LO: 'A1/PFP/FS'
# (7fe0, 0010) Pixel Data                          OW: Array of 3175200 elements

# %%
# Elements we're interested in
# Repetition Time
# Echo Time
# Acquisition Matrix 
# Flip Angle
# Acquisition Number
# Protocol Name
# Slice times = data_set[0x00191029].value

print('The number of TRs collected equals: {0}'.format(len(data_files)))
print('The timing of the TR was: {0} ms'.format(data_set.RepetitionTime))
print('The timing of the TE was: {0} ms'.format(data_set.EchoTime))
print('The acquisition matrix was: {0} '.format(data_set.AcquisitionMatrix))
print('The flip angle in degrees was: {0}'.format(data_set.FlipAngle))
print('The acquistion number was: {0} '.format(data_set.AcquisitionNumber))
print('The name of the protocol was: {0}'.format(data_set.ProtocolName))
print('The name of the scan was: {0}'.format(data_set.SeriesDescription))

# Why use the following format to access information in the header?
print('The In-plane Phase Encoding Direction was:', data_set[int('00181312', 16)].value)
print('The Field of View was:', data_set[int('0051100c', 16)].value) 
#alternative approach for doing hexidecimals--
#print(data_set[0x0051100c].value)
#slice time info doesn't exist with respect to Number of Images in Mosaic there is no hexidecimal 00191029 in this file or the like...
#print(data_set[0x00190100a].value) 
print('The Slice Time was: {0}'.format(data_set[0x00191029].value))
# Out:
# The number of TRs collected equals: 103
# The timing of the TR was: 4200 ms
# The timing of the TE was: 89 ms
# The acquisition matrix was: [140, 0, 0, 140]
# The flip angle in degrees was: 90
# The acquistion number was: 24
# The name of the protocol was: dMRI_AP_REVL
# The name of the scan was: dMRI_AP_REVL
# The In-plane Phase Encoding Direction was: COL
# The Field of View was: FoV 2160*2160
# The Slice Time was: [0.0, 2167.50000001, 155.0, 2322.50000001, 310.0, 2477.50000001, 465.0, 2632.50000001, 620.0, 2787.50000001, 774.99999999, 2942.5, 929.99999999, 3097.5, 1084.99999999, 3252.5, 1240.00000002, 3407.5, 1395.00000002, 3562.5, 1550.00000002, 3717.5, 1705.00000002, 3870.0, 1857.50000001, 4024.99999999, 2012.50000001, 0.0, 2167.50000001, 155.0, 2322.50000001, 310.0, 2477.50000001, 465.0, 2632.50000001, 620.0, 2787.50000001, 774.99999999, 2942.5, 929.99999999, 3097.5, 1084.99999999, 3252.5, 1240.00000002, 3407.5, 1395.00000002, 3562.5, 1550.00000002, 3717.5, 1705.00000002, 3870.0, 1857.50000001, 4024.99999999, 2012.50000001, 0.0, 2167.50000001, 155.0, 2322.50000001, 310.0, 2477.50000001, 465.0, 2632.50000001, 620.0, 2787.50000001, 774.99999999, 2942.5, 929.99999999, 3097.5, 1084.99999999, 3252.5, 1240.00000002, 3407.5, 1395.00000002, 3562.5, 1550.00000002, 3717.5, 1705.00000002, 3870.0, 1857.50000001, 4024.99999999, 2012.50000001]

# %%
# How do I find phase encoding direction information?
import nibabel.nicom.csareader as csareader


rowcol_to_niftidim = {'COL': 'i', 'ROW': 'j'}
pedp_to_sign = {0: '-', 1: ''} 

csa_str = data_set[int('00291010', 16)].value
csa_tr = csareader.read(csa_str)
pedp = csa_tr['tags']['PhaseEncodingDirectionPositive']['items'][0]
ij = rowcol_to_niftidim[data_set[int('00181312', 16)].value]
sign = pedp_to_sign[pedp]
print('The phase encoding direction was: {}{}'.format(ij, sign))
# Out:
# The phase encoding direction was: i
